# %% [markdown]
# <a href="https://colab.research.google.com/github/aryaseptiawan/PCVK_Genap_2022/blob/main/UAS_PCVK_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **KELOMPOK - PARKIR MOBIL (FINAL PROJECT)**
#
# **ALVI RAHMADHANI - 1941720159**
#
# **ARYA SEPTIAWAN - 1941720220**
#
# **BRIAN ADAM BHAGASKARA - 1941720190**

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Mendeteksi Level Keramaian Parkiran Mobil dengan metode Sobel Edge Detection

import cv2 as cv
import numpy as np
import os
from matplotlib import pyplot as plt
from google.colab import drive

#image Path
img0 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/UAS/2012-11-09_08_31_37.jpg')

#convert to grayscale
gray = cv.cvtColor(img0, cv.COLOR_BGR2GRAY)

#removing noises
img = cv.GaussianBlur(gray,(3,3),0)

#sobel edge detection
img_sobelx = cv.Sobel(img, cv.CV_64F, 1, 0, ksize=3)
img_sobely = cv.Sobel(img, cv.CV_64F, 0, 1, ksize=3)

img_sobelxy = cv.addWeighted(cv.convertScaleAbs(img_sobelx), 0.5, cv.convertScaleAbs(img_sobely), 0.5, 0)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(img_sobelxy,cmap = 'gray')

#calculate white and black pixel
number_of_white_pix = np.sum(img_sobelxy == 255)
number_of_black_pix = np.sum(img_sobelxy == 0)
  
print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)

#Create Category by Data Range
print("Level Keramaian : ")
if (number_of_white_pix > 3000):
    print("Sangat Ramai")
elif (number_of_white_pix >= 1000 and number_of_white_pix <= 2999):
    print("Ramai")
elif (number_of_white_pix >= 100 and number_of_white_pix <= 999):
    print("Kurang Ramai")
elif (number_of_white_pix < 100):
    print("Sepi")

threshold = (number_of_white_pix/(number_of_white_pix + number_of_black_pix)) * 100

print("Accurate percentage : ", threshold, "%")
# Out:
# Number of white pixels: 3213
# Number of black pixels: 10216
# Level Keramaian :
# Sangat Ramai
# Accurate percentage :  23.925832154292948 %

# %% [markdown]
# **Gambar pertama menggunakan metode sobel edge detection  menghasilkan level keramaian yang sangat ramai dan mendapatkan persentase sebesar 24%**

# %%
# Mendeteksi Level Keramaian Parkiran Mobil dengan metode Sobel Edge Detection

import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import os
from google.colab import drive

#image Path
img0 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/UAS/2012-11-10_06_32_38.jpg')

#convert to grayscale
gray = cv.cvtColor(img0, cv.COLOR_BGR2GRAY)

#removing noises
img = cv.GaussianBlur(gray,(3,3),0)

#sobel edge detection
img_sobelx = cv.Sobel(img, cv.CV_64F, 1, 0, ksize=3)
img_sobely = cv.Sobel(img, cv.CV_64F, 0, 1, ksize=3)

img_sobelxy = cv.addWeighted(cv.convertScaleAbs(img_sobelx), 0.5, cv.convertScaleAbs(img_sobely), 0.5, 0)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(img_sobelxy,cmap = 'gray')

#calculate white and black pixel
number_of_white_pix = np.sum(img_sobelxy == 255)
number_of_black_pix = np.sum(img_sobelxy == 0)
  
print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)

#Create Category by Data Range
print("Level Keramaian : ")
if (number_of_white_pix > 3000):
    print("Sangat Ramai")
elif (number_of_white_pix >= 1000 and number_of_white_pix <= 2999):
    print("Ramai")
elif (number_of_white_pix >= 100 and number_of_white_pix <= 999):
    print("Kurang Ramai")
elif (number_of_white_pix < 100):
    print("Sepi")

threshold = (number_of_white_pix/(number_of_white_pix + number_of_black_pix)) * 100

print("Accurate percentage : ", threshold, "%")
# Out:
# Number of white pixels: 83
# Number of black pixels: 4114
# Level Keramaian :
# Sepi
# Accurate percentage :  1.9776030497974744 %

# %% [markdown]
# **Untuk gambar kedua menggunakan metode yang sama menghasilkan level keramaian sepi dan mendapatkan persentase sebesar 2%**

# %%
# Mendeteksi Level Keramaian Parkiran Mobil dengan metode Sobel Edge Detection

import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import os
from google.colab import drive

#image Path
img0 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/UAS/2012-11-09_07_26_34.jpg')

#convert to grayscale
gray = cv.cvtColor(img0, cv.COLOR_BGR2GRAY)

#removing noises
img = cv.GaussianBlur(gray,(3,3),0)

#sobel edge detection
img_sobelx = cv.Sobel(img, cv.CV_64F, 1, 0, ksize=3)
img_sobely = cv.Sobel(img, cv.CV_64F, 0, 1, ksize=3)

img_sobelxy = cv.addWeighted(cv.convertScaleAbs(img_sobelx), 0.5, cv.convertScaleAbs(img_sobely), 0.5, 0)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(img_sobelxy,cmap = 'gray')

#calculate white and black pixel
number_of_white_pix = np.sum(img_sobelxy == 255)
number_of_black_pix = np.sum(img_sobelxy == 0)
  
print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)

#Create Category by Data Range
print("Level Keramaian : ")
if (number_of_white_pix > 3000):
    print("Sangat Ramai")
elif (number_of_white_pix >= 1000 and number_of_white_pix <= 2999):
    print("Ramai")
elif (number_of_white_pix >= 100 and number_of_white_pix <= 999):
    print("Kurang Ramai")
elif (number_of_white_pix < 100):
    print("Sepi")

threshold = (number_of_white_pix/(number_of_white_pix + number_of_black_pix)) * 100

print("Accurate percentage : ", threshold, "%")
# Out:
# Number of white pixels: 1069
# Number of black pixels: 7535
# Level Keramaian :
# Ramai
# Accurate percentage :  12.424453742445374 %

# %% [markdown]
# **Pada percobaan gambar ketiga menggunakan metode yang sama menghasilkan level keramaian parkiran yang ramai dan mendapatkan persentase sebesar 12%**

# %%
# Mendeteksi Parkiran Mobil dengan metode Car Detection

import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt


# Menggunakan haarcascade Mendeteksi Mobil
cascade_car = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_MM/Images/UAS/haarcascade_car.xml')

parkiran = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/UAS/2012-11-10_08_47_45.jpg',0)
parkiran1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/UAS/2012-11-10_08_47_45.jpg',0)
roi_car1 = cascade_car.detectMultiScale(parkiran1)

# Menggunakan parameter deteksi multiskala
roi_car = cascade_car.detectMultiScale(parkiran) 
for(x,y,w,h) in roi_car: 
 cv.rectangle(parkiran,(x,y),(x+w,y+h),(255,0,255),3) 

# untuk membuat objek gambar
plt.figure(figsize = (20,20)) 

# untuk Konversi Ruang Warna
f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(parkiran1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(parkiran1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(parkiran, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(parkiran, cv.COLOR_BGR2RGB))
plt.show()

# %%
# Mendeteksi Parkiran Mobil dengan metode Car Detection

import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt


cascade_car = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_MM/Images/UAS/haarcascade_car.xml')

parkiran = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/UAS/2012-11-09_07_26_34.jpg',0)
parkiran1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/UAS/2012-11-09_07_26_34.jpg',0)

roi_car = cascade_car.detectMultiScale(parkiran1)
for(x,y,w,h) in roi_car:
 cv.rectangle(parkiran1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(parkiran)
plt.subplot(122),plt.imshow(parkiran1)
plt.show()

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import cv2
import math
from google.colab.patches import cv2_imshow

# %%
car_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK_MM/Images/UAS/haarcascade_car.xml')
parkiran = cv2.imread('/content/drive/MyDrive/PCVK_MM/Images/UAS/2012-11-09_08_31_37.jpg')
cv2_imshow(parkiran)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F7F06BF9A10>

# %%
parkiran2 = cv2.imread('/content/drive/MyDrive/PCVK_MM/Images/UAS/2012-11-09_08_31_37.jpg')
cars = car_cascade.detectMultiScale(parkiran2)

# %%
jumlah =0;
gray = cv2.cvtColor(parkiran, cv2.COLOR_BGR2GRAY)
cars = car_cascade.detectMultiScale(parkiran)
for(x,y,w,h) in cars: 
 cv2.rectangle(parkiran,(x,y),(x+w,y+h),(0,255,0),3) 
 jumlah+=1;
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv2.cvtColor(parkiran2, cv2.COLOR_BGR2RGB))
axarr[0].imshow(cv2.cvtColor(parkiran2, cv2.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv2.cvtColor(parkiran, cv2.COLOR_BGR2RGB))
axarr[1].imshow(cv2.cvtColor(parkiran, cv2.COLOR_BGR2RGB))
plt.show()
print('Jumlah mobil yang terdeteksi: ')
print(jumlah)
# Out:
# Jumlah mobil yang terdeteksi:
# 63
